# %%
from src.predict_labels import CellEmbeddingModelWrapper
from utils.embeddings import compare_embeddings, compare_embeddings_when_transposed

# %% [markdown]
# ### Configs

# %%
CE_MODEL = '../models/ce.model'
FE_MODEL = '../models/fe.model'
CL_MODEL = '../models/cl.model'
W2V = '../models/glove.840B.300d.txt'
INFERSENT_MODEL = '../models/infersent1.pkl'
VOCAB_SIZE = 60000

# %% [markdown]
# ### Load model

# %%
model = CellEmbeddingModelWrapper(CE_MODEL, FE_MODEL, CL_MODEL, W2V, VOCAB_SIZE, INFERSENT_MODEL)
# Out:
# loading word vectors...
# loading word embeddings...
# creating dict...
# embeddings loaded!

# %% [markdown]
# ### Comparison function

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'Reference', 'Reference_copy')
# Out:
# Generating embedding for ../data/Book1.xls and Reference
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:01<00:00, 54.09it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])
# Generating embedding for ../data/Book1.xls and Reference_copy
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:01<00:00, 52.36it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'Reference', 'Reference_update_single_cell')
# Out:
# Generating embedding for ../data/Book1.xls and Reference
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:01<00:00, 55.55it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])
# Generating embedding for ../data/Book1.xls and Reference_update_single_cell
# initialize 57 text sentences...
# 100%|██████████| 57/57 [00:01<00:00, 56.55it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'Reference', 'Reference_with_unit_updated')
# Out:
# Generating embedding for ../data/Book1.xls and Reference
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:00<00:00, 56.63it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])
# Generating embedding for ../data/Book1.xls and Reference_with_unit_updated
# initialize 57 text sentences...
# 100%|██████████| 57/57 [00:01<00:00, 56.40it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'Reference', 'Reference_without_format')
# Out:
# Generating embedding for ../data/Book1.xls and Reference
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:00<00:00, 56.08it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])
# Generating embedding for ../data/Book1.xls and Reference_without_format
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:00<00:00, 56.45it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'transposed', 'transposed_update_unit')
# Out:
# Generating embedding for ../data/Book1.xls and transposed
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:00<00:00, 56.93it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([15, 38, 552])
# Generating embedding for ../data/Book1.xls and transposed_update_unit
# initialize 57 text sentences...
# 100%|██████████| 57/57 [00:01<00:00, 56.77it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([15, 38, 552])

# %%
compare_embeddings_when_transposed(model, '../data/Book1.xls', '../data/Book1.xls', 'Reference', 'transposed')
# Out:
# Generating embedding for ../data/Book1.xls and Reference
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:01<00:00, 55.86it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([38, 15, 552])
# Generating embedding for ../data/Book1.xls and transposed
# initialize 56 text sentences...
# 100%|██████████| 56/56 [00:00<00:00, 56.82it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([15, 38, 552])

# %%
compare_embeddings_when_transposed(model, '../data/Book1.xls', '../data/Book1.xls', 'num_row', 'num_column')
# Out:
# Generating embedding for ../data/Book1.xls and num_row
# initialize 10 text sentences...
# 100%|██████████| 10/10 [00:00<00:00, 85.21it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([5, 10, 552])
# Generating embedding for ../data/Book1.xls and num_column
# initialize 10 text sentences...
# 100%|██████████| 10/10 [00:00<00:00, 86.03it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([10, 5, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'something', 'something')
# Out:
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 86.56it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 74.93it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'something', 'something_horizontal')
# Out:
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 83.49it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])
# Generating embedding for ../data/Book1.xls and something_horizontal
# initialize 2 text sentences...
# 100%|██████████| 2/2 [00:00<00:00, 84.86it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])

# %%
compare_embeddings(model, '../data/Book1.xls', '../data/Book1.xls', 'something', 'something_vertical')
# Out:
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 82.56it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])
# Generating embedding for ../data/Book1.xls and something_vertical
# initialize 2 text sentences...
# 100%|██████████| 2/2 [00:00<00:00, 87.57it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])

# %%
compare_embeddings_when_transposed(model, '../data/Book1.xls', '../data/Book1.xls', 'something', 'something')
# Out:
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 82.03it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])
# Generating embedding for ../data/Book1.xls and something
# initialize 1 text sentences...
# 100%|██████████| 1/1 [00:00<00:00, 78.04it/s]
# initialize 0 numeric sentences...
# 0it [00:00, ?it/s]
# torch.Size([6, 6, 552])
